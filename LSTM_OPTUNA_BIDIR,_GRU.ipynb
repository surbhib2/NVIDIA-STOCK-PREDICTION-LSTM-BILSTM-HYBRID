# %%
# Out:
# [I 2025-10-15 17:53:58,879] A new study created in memory with name: no-name-55fc5389-ac21-4cdb-a14e-9bf2e2012b37
# ...
# Prepared data shape: (1254, 15)
# ['Open_NVDA', 'High_NVDA', 'Low_NVDA', 'Close_NVDA', 'Volume_NVDA', 'SPY_Close', 'Return', 'SMA_10', 'SMA_30', 'EMA_10', 'EMA_30', 'BB_upper', 'BB_lower', 'RSI', 'MACD']
# Dates range: 2020-10-16 00:00:00 to 2025-10-14 00:00:00
# Test start index (in original df): 1164
# Starting Optuna tuning...
